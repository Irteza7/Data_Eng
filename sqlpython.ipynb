# %%
# %load_ext sql
import ibm_db
import ibm_db_sa
import csv, sqlite3
import pandas as pd

con = sqlite3.connect("RealWorldData.db")
cur = con.cursor()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///RealWorldData.db

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv")

# %%
df.head(5)
# Out:
#    School_ID                                     NAME_OF_SCHOOL
# 0     610038                  Abraham Lincoln Elementary School  \
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State
# 0                                 ES        615 W Kemper Pl  Chicago    IL  \
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number
# 0     60614  (773) 534-5720  \
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
df.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA",con,if_exists='replace', index=False, method="multi")
# Out:
# 566

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")

df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv")
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")
# Out:
# 533

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('CHICAGO_PUBLIC_SCHOOLS_DATA',)]

# %%
cur.execute('PRAGMA table_info(CHICAGO_PUBLIC_SCHOOLS_DATA)')
results = cur.fetchall()
for row in results:
    print(row[1])  # Column name is at index 1 in each row
# Out:
# School_ID
# NAME_OF_SCHOOL
# Elementary, Middle, or High School
# Street_Address
# City
# State
# ZIP_Code
# Phone_Number
# Link
# Network_Manager
# Collaborative_Name
# Adequate_Yearly_Progress_Made_
# Track_Schedule
# CPS_Performance_Policy_Status
# CPS_Performance_Policy_Level
# HEALTHY_SCHOOL_CERTIFIED
# Safety_Icon
# SAFETY_SCORE
# Family_Involvement_Icon
# Family_Involvement_Score
# Environment_Icon
# Environment_Score
# Instruction_Icon
# Instruction_Score
# Leaders_Icon
# Leaders_Score
# Teachers_Icon
# Teachers_Score
# Parent_Engagement_Icon
# Parent_Engagement_Score
# Parent_Environment_Icon
# Parent_Environment_Score
# AVERAGE_STUDENT_ATTENDANCE
# Rate_of_Misconducts__per_100_students_
# Average_Teacher_Attendance
# Individualized_Education_Program_Compliance_Rate
# Pk_2_Literacy__
# Pk_2_Math__
# Gr3_5_Grade_Level_Math__
# Gr3_5_Grade_Level_Read__
# Gr3_5_Keep_Pace_Read__
# Gr3_5_Keep_Pace_Math__
# Gr6_8_Grade_Level_Math__
# Gr6_8_Grade_Level_Read__
# ...

# %%
# %%sql
# SELECT count(name) as No_of_Cols FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA')
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(78,)]

# %%
# %%sql
# SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA')
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
#  ('Leaders_Score', 'TEXT', 4),
# ...

# %%
# %%sql
# Select ("Elementary, Middle, or High School") from CHICAGO_PUBLIC_SCHOOLS_DATA limit 10;
# Select count("Elementary, Middle, or High School") from CHICAGO_PUBLIC_SCHOOLS_DATA where "Elementary, Middle, or High School" = "ES";
# select max(SAFETY_SCORE) from CHICAGO_PUBLIC_SCHOOLS_DATA
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# Done.
# Done.
# [(99.0,)]

# %%
# %%sql
# select AVERAGE_STUDENT_ATTENDANCE from CHICAGO_PUBLIC_SCHOOLS_DATA order by AVERAGE_STUDENT_ATTENDANCE desc limit 10
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('98.40%',),
#  ('97.80%',),
#  ('97.60%',),
#  ('97.60%',),
#  ('97.60%',),
#  ('97.50%',),
#  ('97.40%',),
#  ('97.40%',),
#  ('97.30%',),
#  ('97.20%',)]

# %%
# %%sql
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from CHICAGO_PUBLIC_SCHOOLS_DATA
# order by AVERAGE_STUDENT_ATTENDANCE limit 5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %%
# %%sql
# select NAME_OF_SCHOOL, REPLACE(AVERAGE_STUDENT_ATTENDANCE, '%', '') as avg_attendance from CHICAGO_PUBLIC_SCHOOLS_DATA
# order by AVERAGE_STUDENT_ATTENDANCE limit 5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00')]

# %%
# %%sql
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from CHICAGO_PUBLIC_SCHOOLS_DATA
# where AVERAGE_STUDENT_ATTENDANCE <= "70%"
# order by Average_Student_Attendance
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from CHICAGO_PUBLIC_SCHOOLS_DATA \
     where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %%sql
# select COMMUNITY_AREA_NAME, count(COLLEGE_ENROLLMENT) as quantity from CHICAGO_PUBLIC_SCHOOLS_DATA group by COMMUNITY_AREA_NAME
# order by quantity desc
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('AUSTIN', 23),
#  ('SOUTH LAWNDALE', 22),
#  ('WEST TOWN', 20),
#  ('ENGLEWOOD', 17),
#  ('NORTH LAWNDALE', 16),
#  ('NEAR WEST SIDE', 16),
#  ('WEST ENGLEWOOD', 13),
#  ('ROSELAND', 13),
#  ('NEW CITY', 13),
#  ('HUMBOLDT PARK', 13),
#  ('EAST GARFIELD PARK', 13),
#  ('BELMONT CRAGIN', 12),
#  ('LOWER WEST SIDE', 11),
#  ('LOGAN SQUARE', 11),
#  ('LAKE VIEW', 11),
#  ('DOUGLAS', 11),
#  ('WEST PULLMAN', 10),
#  ('GREATER GRAND CROSSING', 10),
#  ('GAGE PARK', 10),
#  ('AUBURN GRESHAM', 10),
#  ('WEST RIDGE', 9),
#  ('WASHINGTON HEIGHTS', 9),
#  ('SOUTH SHORE', 9),
#  ('IRVING PARK', 9),
#  ('CHATHAM', 9),
#  ('WOODLAWN', 8),
#  ('WEST GARFIELD PARK', 8),
#  ('NORWOOD PARK', 8),
#  ('GRAND BOULEVARD', 8),
#  ('BRIGHTON PARK', 8),
#  ('ASHBURN', 8),
#  ('ALBANY PARK', 8),
#  ('UPTOWN', 7),
#  ('SOUTH CHICAGO', 7),
#  ('PORTAGE PARK', 7),
#  ('NORTH CENTER', 7),
#  ('NEAR NORTH SIDE', 7),
#  ('LINCOLN PARK', 7),
#  ('KENWOOD', 7),
# ...

# %%
# %%sql
# select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) as TOTAL_ENROLLMENT from CHICAGO_PUBLIC_SCHOOLS_DATA group by COMMUNITY_AREA_NAME
# order by TOTAL_ENROLLMENT desc
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('SOUTH LAWNDALE', 14793),
#  ('BELMONT CRAGIN', 14386),
#  ('AUSTIN', 10933),
#  ('GAGE PARK', 9915),
#  ('BRIGHTON PARK', 9647),
#  ('WEST TOWN', 9429),
#  ('HUMBOLDT PARK', 8620),
#  ('WEST RIDGE', 8197),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('IRVING PARK', 7764),
#  ('NORTH CENTER', 7541),
#  ('LOGAN SQUARE', 7351),
#  ('LOWER WEST SIDE', 7257),
#  ('CHICAGO LAWN', 7086),
#  ('LAKE VIEW', 7055),
#  ('ROSELAND', 7020),
#  ('PORTAGE PARK', 6954),
#  ('ALBANY PARK', 6864),
#  ('ENGLEWOOD', 6832),
#  ('ASHBURN', 6483),
#  ('NORWOOD PARK', 6469),
#  ('WEST ENGLEWOOD', 5946),
#  ('LINCOLN PARK', 5615),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('NORTH LAWNDALE', 5146),
#  ('CHATHAM', 5042),
#  ('ARCHER HEIGHTS', 4823),
#  ('DOUGLAS', 4670),
#  ('EDGEWATER', 4600),
#  ('DUNNING', 4568),
#  ('GARFIELD RIDGE', 4552),
#  ('SOUTH SHORE', 4543),
#  ('UPTOWN', 4388),
#  ('KENWOOD', 4287),
#  ('NORTH PARK', 4210),
# ...

# %%
# %%sql
# select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) as TOTAL_ENROLLMENT from CHICAGO_PUBLIC_SCHOOLS_DATA group by COMMUNITY_AREA_NAME
# order by TOTAL_ENROLLMENT limit 5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# %%sql
# select NAME_OF_SCHOOL, SAFETY_SCORE from CHICAGO_PUBLIC_SCHOOLS_DATA
# where safety_score !='None'
# order by SAFETY_SCORE limit 5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Edmond Burke Elementary School', 1.0),
#  ("Luke O'Toole Elementary School", 5.0),
#  ('George W Tilton Elementary School', 6.0),
#  ('Foster Park Elementary School', 11.0),
#  ('Emil G Hirsch Metropolitan High School', 13.0)]

# %%
# %%sql
# select hardship_index from CENSUS_DATA CD, CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# where CD.community_area_number = CPS.community_area_number
# and college_enrollment = 4368
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(6.0,)]
